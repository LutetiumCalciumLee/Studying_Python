# %% [markdown]
# ## 문제
# 정수 n을 입력하고 n까지의 짝수의 합
#
# ---
#
# ## 입력
#
# 1<=n<=10000
#
# ---
#
# ## 출력
# ---
# n
# ---

# %%
Number = int(input("1부터 10000 사이의 정수를 입력하시고 Enter키를 누르세요 "))

EvenNumSum = 0

for i in range (0,Number+1,2):
  EvenNumSum += i
print (EvenNumSum)
# Out:
# 1부터 10000 사이의 정수를 입력하시고 Enter키를 누르세요 30
# 240
